# %%
# %pip install scrapy pandas numpy pillow matplotlib scikit-learn
# Out:
# Requirement already satisfied: scrapy in e:\anaconda3\anaconda\lib\site-packages (2.11.1)
# Requirement already satisfied: pandas in e:\anaconda3\anaconda\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in e:\anaconda3\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: pillow in e:\anaconda3\anaconda\lib\site-packages (10.2.0)
# Requirement already satisfied: matplotlib in e:\anaconda3\anaconda\lib\site-packages (3.8.0)
# Requirement already satisfied: scikit-learn in e:\anaconda3\anaconda\lib\site-packages (1.2.2)
# Requirement already satisfied: Twisted>=18.9.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (23.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (42.0.5)
# Requirement already satisfied: cssselect>=0.9.1 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (24.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: itemadapter>=0.1.0 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: setuptools in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (68.0.0)
# Requirement already satisfied: packaging in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: lxml>=4.4.1 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in e:\anaconda3\anaconda\lib\site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda3\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda3\anaconda\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\anaconda3\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda3\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda3\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda3\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda3\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda3\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.3.2 in e:\anaconda3\anaconda\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.1.1 in e:\anaconda3\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda3\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: cffi>=1.12 in e:\anaconda3\anaconda\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in e:\anaconda3\anaconda\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six in e:\anaconda3\anaconda\lib\site-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in e:\anaconda3\anaconda\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.2.0)
# Requirement already satisfied: pyasn1-modules in e:\anaconda3\anaconda\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in e:\anaconda3\anaconda\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: automat>=0.8.0 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: constantly>=15.1 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=22.10.0 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in e:\anaconda3\anaconda\lib\site-packages (from Twisted>=18.9.0->scrapy) (4.9.0)
# Requirement already satisfied: idna in e:\anaconda3\anaconda\lib\site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in e:\anaconda3\anaconda\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in e:\anaconda3\anaconda\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in e:\anaconda3\anaconda\lib\site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: pycparser in e:\anaconda3\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda3\anaconda\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda3\anaconda\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda3\anaconda\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 你好，笔记世界！
#
# Jupyter笔记是一个开源网页应用，通过Jupyter笔记，你可以创建和分享包含代码、公式、可视化、描述性文本的笔记。
# 使用方式多种多样：数据清洗和转换、数值模拟、统计模型、数据可视化、机器学习以及更多。

# %% [markdown]
# ## 你好世界
#
# 笔记代码格输入以下代码并执行：
#
# ```python
# print("Hello, world!")
# ```
#
# 观察到显示出
#
# ```
# Hello, world!
# ```

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## 简单计算
#
# Jupyter中同样可以方便的进行简单的数值计算。
# 代码格中输入计算式：
#
# ```python
# 11 - (7 + <你的学号>) * 3
# ```
#
# 其中，用你的学号替换`<你的学号>`。
# 观察到计算出的相应结果。

# %%
11 - (7 + 2022141080034) * 3
# Out:
# -6066423240112

# %% [markdown]
# ## 打印系统版本
#
# Python2和Python3版本有较大的差别，而Python3不同版本之间也略有差别，我们需要关注自己使用的Python版本。
# Jupyter也运行着某个版本的Python。通过以下命令获得Python版本
#
# ```python
# import sys
# sys.version
# ```
#
# 将显示当前Python版本。

# %%
import sys
sys.version
# Out:
# '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# ## 运行Python脚本
#
# Python脚本就是Python命令的序列。笔记本中的代码格可以直接填写复制的Python脚本
#
# ### 编写脚本文件
#
# 在代码格中填入以下脚本
#
# ```python
# total = 0
# for value in range(1, 101):
#     total = total + value
# print(total)
# ```
#
# 执行该代码格，将看到Python计算并显示出正确结果：
#
# ```
# 5050
# ```

# %%
total = 0
for value in range(1, 101):
    total = total + value
print(total)
# Out:
# 5050

# %%
from matplotlib import pyplot as plt
from PIL import Image

husky = Image.open("husky.jpg")

fig, ax = plt.subplots()
ax.imshow(husky)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

mu = 200
sigma = 25
n_bins = 50
x = np.random.normal(mu, sigma, size=100)

fig, ax = plt.subplots(figsize=(8, 4))

# plot the cumulative histogram
n, bins, patches = ax.hist(x, n_bins, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the expected distribution.
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
y = y.cumsum()
y /= y[-1]

ax.plot(bins, y, 'k--', linewidth=1.5, label='Theoretical')

# Overlay a reversed cumulative histogram.
ax.hist(x, bins=bins, density=True, histtype='step', cumulative=-1,
        label='Reversed emp.')

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms')
ax.set_xlabel('Annual rainfall (mm)')
ax.set_ylabel('Likelihood of occurrence')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch
import numpy as np

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.27, .56, .17]
labels = ['Approve', 'Disapprove', 'Undecided']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.33, .54, .07, .06]
age_labels = ['Under 35', '35-49', '50-65', 'Over 65']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Age of approvers')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig = plt.figure(figsize=(7, 9))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])

#  Varying density along a streamline
ax0 = fig.add_subplot(gs[0, 0])
ax0.streamplot(X, Y, U, V, density=[0.5, 1])
ax0.set_title('Varying Density')

# Varying color along a streamline
ax1 = fig.add_subplot(gs[0, 1])
strm = ax1.streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn')
fig.colorbar(strm.lines)
ax1.set_title('Varying Color')

#  Varying line width along a streamline
ax2 = fig.add_subplot(gs[1, 0])
lw = 5*speed / speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)
ax2.set_title('Varying Line Width')

# Controlling the starting points of the streamlines
seed_points = np.array([[-2, -1, 0, 1, 2, -1], [-2, -1,  0, 1, 2, 2]])

ax3 = fig.add_subplot(gs[1, 1])
strm = ax3.streamplot(X, Y, U, V, color=U, linewidth=2,
                      cmap='autumn', start_points=seed_points.T)
fig.colorbar(strm.lines)
ax3.set_title('Controlling Starting Points')

# Displaying the starting points with blue symbols.
ax3.plot(seed_points[0], seed_points[1], 'bo')
ax3.set(xlim=(-w, w), ylim=(-w, w))

# Create a mask
mask = np.zeros(U.shape, dtype=bool)
mask[40:60, 40:60] = True
U[:20, :20] = np.nan
U = np.ma.array(U, mask=mask)

ax4 = fig.add_subplot(gs[2:, :])
ax4.streamplot(X, Y, U, V, color='r')
ax4.set_title('Streamplot with Masking')

ax4.imshow(~mask, extent=(-w, w, -w, w), alpha=0.5, cmap='gray', aspect='auto')
ax4.set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
# %pip install gym pygame
# %pip install ipympl

# %%
# %matplotlib widget

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.axis("off")

# %%
# %matplotlib widget

import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8,3))
ax1.axis("off")

# %%
# %matplotlib widget

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.axis("off")
