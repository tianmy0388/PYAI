# %% [markdown]
# ## Scrapy数据收集

# %% [markdown]
# https://scrapy.org/
#
# ![Alt text](image.png)

# %%
# %pip install scrapy "cryptography<3.4" "pyopenssl<22"

# %% [markdown]
# 注意：在notebook中运行scrapy，遇到`ReactorNotRestartable`，需重启kernel

# %% [markdown]
# 例：
# http://books.toscrape.com/
#
# 目标：爬取书籍的信息

# %%
import scrapy


class BookSpider(scrapy.Spider):
    name = "quotes"

    start_urls = [
        'http://books.toscrape.com/index.html',
    ]

    def parse(self, response):
        print(response.url)
        print(response.status)
        print(response.headers)
        print(response.body)

# %%
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess()
process.crawl(BookSpider)
process.start()
# Out:
# 2023-10-09 10:57:30 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-10-09 10:57:30 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.13, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.4.0, Python 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:38:29) [Clang 13.0.1 ], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 37.0.4, Platform macOS-14.0-arm64-arm-64bit
# 2023-10-09 10:57:30 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-10-09 10:57:30 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-09 10:57:30 [scrapy.extensions.telnet] INFO: Telnet Password: 0ae6736fa79e4375
# 2023-10-09 10:57:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-09 10:57:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-09 10:57:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-09 10:57:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-10-09 10:57:30 [scrapy.core.engine] INFO: Spider opened
# 2023-10-09 10:57:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-09 10:57:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-10-09 10:57:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/index.html> (referer: None)
# 2023-10-09 10:57:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-10-09 10:57:31 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 228,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 51489,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.856958,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 10, 9, 2, 57, 31, 546127),
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 10,
#  'memusage/max': 127401984,
#  'memusage/startup': 127401984,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 10, 9, 2, 57, 30, 689169)}
# 2023-10-09 10:57:31 [scrapy.core.engine] INFO: Spider closed (finished)
# http://books.toscrape.com/index.html
# 200
# {b'Content-Length': [b'51294'], b'Date': [b'Mon, 09 Oct 2023 02:57:31 GMT'], b'Content-Type': [b'text/html'], b'Last-Modified': [b'Wed, 08 Feb 2023 21:02:32 GMT'], b'Etag': [b'"63e40de8-c85e"'], b'Accept-Ranges': [b'bytes']}
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.ico" />\n        \n\n        \n        \n    \n    \n        <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css" />\n    \n    <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" />\n    <link rel="stylesheet" type="text/css" href="static/oscar/css/datetimepicker.css" />\n\n\n        \n        \n\n        \n\n        \n            \n            \n\n        \n    </head>\n\n    <body id="default" class="default">\n        \n        \n    \n    \n    <header class="header container-fluid">\n        <div class="page_inner">\n            <div class="row">\n                <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>\n\n                \n            </div>\n        </div>\n    </header>\n\n    \n    \n<div class="container-fluid page">\n    <div class="page_inner">\n        \n    <ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>\n\n        <div class="row">\n\n            <aside class="sidebar col-sm-4 col-md-3">\n                \n                <div id="promotions_left">\n                    \n                </div>\n                \n    \n    \n        \n        <div class="side_categories">\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/historical-fiction_4/index.html">\n                            \n                                Historical Fiction\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>\n\n                        </li>\n           ...

# %% [markdown]
# ```html
# <article class="product_pod">
#   <div class="image_container">
#     <a href="a-light-in-the-attic_1000/index.html"
#       ><img
#         src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"
#         alt="A Light in the Attic"
#         class="thumbnail"
#     /></a>
#   </div>
#
#   <p class="star-rating Three">
#     <i class="icon-star"></i>
#     <i class="icon-star"></i>
#     <i class="icon-star"></i>
#     <i class="icon-star"></i>
#     <i class="icon-star"></i>
#   </p>
#
#   <h3>
#     <a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic"
#       >A Light in the ...</a
#     >
#   </h3>
#
#   <div class="product_price">
#     <p class="price_color">£51.77</p>
#
#     <p class="instock availability">
#       <i class="icon-ok"></i>
#
#       In stock
#     </p>
#
#     <form>
#       <button
#         type="submit"
#         class="btn btn-primary btn-block"
#         data-loading-text="Adding..."
#       >
#         Add to basket
#       </button>
#     </form>
#   </div>
# </article>
# ```

# %%
import scrapy


class BookSpider(scrapy.Spider):
    name = "quotes"

    start_urls = [
        'http://books.toscrape.com/index.html',
    ]

    def parse(self, response):
        # css selector
        print(response.css('h3 a'))
        print(response.css('h3 a').getall())
        print(response.css('h3 a::text').getall())
        print(response.css('h3 a::text').get())  # returns the first element

        # regex
        print(response.css('h3 a::text').re(r'[^\.]+'))

        # xpath
        print(response.xpath('//h3/a/text()').get())

        # final version
        # print(response.css('h3 a::attr(title)').getall())

# %%
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess()
process.crawl(BookSpider)
process.start()
# Out:
# 2023-10-09 11:30:47 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-10-09 11:30:47 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.13, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.4.0, Python 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:38:29) [Clang 13.0.1 ], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 37.0.4, Platform macOS-14.0-arm64-arm-64bit
# 2023-10-09 11:30:47 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-10-09 11:30:47 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-09 11:30:47 [scrapy.extensions.telnet] INFO: Telnet Password: 91aae72c26491261
# 2023-10-09 11:30:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-09 11:30:47 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-09 11:30:47 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-09 11:30:47 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-10-09 11:30:47 [scrapy.core.engine] INFO: Spider opened
# 2023-10-09 11:30:47 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-09 11:30:47 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-10-09 11:30:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/index.html> (referer: None)
# 2023-10-09 11:30:48 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-10-09 11:30:48 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 228,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 51489,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.764823,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 10, 9, 3, 30, 48, 522948),
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 10,
#  'memusage/max': 109428736,
#  'memusage/startup': 109428736,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 10, 9, 3, 30, 47, 758125)}
# 2023-10-09 11:30:48 [scrapy.core.engine] INFO: Spider closed (finished)
# [<Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/a-light-in-the-att...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/tipping-the-velvet...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/soumission_998/ind...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/sharp-objects_997/...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/sapiens-a-brief-hi...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/the-requiem-red_99...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/the-dirty-little-s...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/the-coming-woman-a...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/the-boys-in-the-bo...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/the-black-maria_99...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/starving-hearts-tr...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/shakespeares-sonne...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/set-me-free_988/in...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/scott-pilgrims-pre...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/rip-it-up-and-star...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/our-band-could-be-...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/olio_984/index.htm...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/mesaerion-the-best...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/libertarianism-for...'>, <Selector xpath='descendant-or-self::h3/descendant-or-self::*/a' data='<a href="catalogue/its-only-the-himal...'>]
# ['<a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>', '<a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a>', '<a href="catalogue/soumission_998/index.html" title="Soumission">Soumission</a>', '<a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a>', '<a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a>', '<a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a>', '<a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a>', '<a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" title="The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull">The Coming Woman: A ...</a>', '<a href="catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html" title="The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics">The Boys in the ...</a>', '<a href="catalogue/the-black-maria_991/index.html" title="The Black Maria">The Black Maria</a>', '<a href="catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html" title="Starving Hearts (Triangular Trade Trilogy, #1)">Starving Hearts (Triangular Trade ...</a>', '<a href="catalogue/shakespeares-sonnets_989/index.html" title="Shakespeare\'s Sonnets">Shakespeare\'s Sonnets</a>', '<a href="catalogue/set-me-free_988/index.html" title="Set Me Free">Set Me Free</a>', '<a href="catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html" title="Scott Pilgrim\'s Precious Little Life (Scott Pilgrim #1)">Scott Pilgrim\'s Precious Little ...</a>', '<a href="catalogue/rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">Rip it Up and ...</a>', '<a href="catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html" title="Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991">Our Band Could Be ...</a>', '<a href="catalogue/olio_984/index.html" title="Olio">Olio</a>', '<a href="catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html" title="Mesaerion: The Best Science Fiction Stories 1800-1849">Mesaerion: The Best Science ...</a>', '<a href="catalogue/libertarianism-for-beginners_982/index.html" title="Libertarianism for Beginners">Libertarianism for Beginners</a>', '<a href="catalogue/its-only-the-himalayas_981/index.html" title="It\'s Only the Himalayas">It\'s Only the Himalayas</a>']
# ['A Light in the ...', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History ...', 'The Requiem Red', 'The Dirty Little Secrets ...', 'The Coming Woman: A ...', 'The Boys in the ...', 'The Black Maria', 'Starving Hearts (Triangular Trade ...', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little ...", 'Rip it Up and ...', 'Our Band Could Be ...', 'Olio', 'Mesaerion: The Best Science ...', 'Libertarianism for Beginners', "It's Only the Himalayas"]
# A Light in the ...
# ['A Light in the ', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History ', 'The Requiem Red', 'The Dirty Little Secrets ', 'The Coming Woman: A ', 'The Boys in the ', 'The Black Maria', 'Starving Hearts (Triangular Trade ', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little ", 'Rip it Up and ', 'Our Band Could Be ', 'Olio', 'Mesaerion: The Best Science ', 'Libertarianism for Beginners', "It's Only the Himalayas"]
# A Light in the ...
# ['A Light in the Attic', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History of Humankind', 'The Requiem Red', 'The Dirty Little Secrets of Getting Your Dream Job', 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'The Black Maria', 'Starving Hearts (Triangular Trade Trilogy, #1)', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Rip it Up and Start Again', 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Olio', 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'Libertarianism for Beginners', "It's Only the Himalayas"]

# %% [markdown]
# 更多页面
# - http://books.toscrape.com/catalogue/page-1.html
# - http://books.toscrape.com/catalogue/page-2.html
# - ……

# %%
import scrapy


class BookSpider(scrapy.Spider):
    name = "quotes"

    start_urls = [
        'http://books.toscrape.com/catalogue/page-1.html',
        'http://books.toscrape.com/catalogue/page-2.html',
        # ...
    ]

    # def start_requests(self):
    #     url_template = 'http://books.toscrape.com/catalogue/page-{}.html'
    #     for i in range(1, 6):
    #         url = url_template.format(i)
    #         yield scrapy.Request(url, callback=self.parse)

    def parse(self, response):
        items = response.css("article.product_pod")
        for item in items:
            title = item.css('h3 a::attr(title)').get()
            price = item.css('div.product_price p.price_color::text').get()
            print(title, price)

# %%
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess()
process.crawl(BookSpider)
process.start()
# Out:
# 2023-10-09 11:44:01 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-10-09 11:44:01 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.13, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.4.0, Python 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:38:29) [Clang 13.0.1 ], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 37.0.4, Platform macOS-14.0-arm64-arm-64bit
# 2023-10-09 11:44:01 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-10-09 11:44:01 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-09 11:44:01 [scrapy.extensions.telnet] INFO: Telnet Password: 8d5f90336c765d74
# 2023-10-09 11:44:01 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-09 11:44:01 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-09 11:44:01 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-09 11:44:01 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-10-09 11:44:01 [scrapy.core.engine] INFO: Spider opened
# 2023-10-09 11:44:01 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-09 11:44:01 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2023-10-09 11:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-1.html> (referer: None)
# 2023-10-09 11:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-4.html> (referer: None)
# 2023-10-09 11:44:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-5.html> (referer: None)
# A Light in the Attic £51.77
# Tipping the Velvet £53.74
# Soumission £50.10
# Sharp Objects £47.82
# Sapiens: A Brief History of Humankind £54.23
# The Requiem Red £22.65
# The Dirty Little Secrets of Getting Your Dream Job £33.34
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull £17.93
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics £22.60
# The Black Maria £52.15
# Starving Hearts (Triangular Trade Trilogy, #1) £13.99
# Shakespeare's Sonnets £20.66
# Set Me Free £17.46
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) £52.29
# Rip it Up and Start Again £35.02
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 £57.25
# Olio £23.88
# Mesaerion: The Best Science Fiction Stories 1800-1849 £37.59
# Libertarianism for Beginners £51.33
# It's Only the Himalayas £45.17
# The Nameless City (The Nameless City #1) £38.16
# The Murder That Never Was (Forensic Instincts #5) £54.11
# The Most Perfect Thing: Inside (and Outside) a Bird's Egg £42.96
# The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy £23.89
# The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing £16.77
# The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer £20.59
# The Gutsy Girl: Escapades for Your Life of Epic Adventure £37.13
# The Electric Pencil: Drawings from Inside State Hospital No. 3 £56.06
# The Death of Humanity: and the Case for Life £58.11
# The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life £49.05
# The Art Forger £40.76
# The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind £19.73
# The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution £32.24
# Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up £41.83
# Soul Reader £39.58
# Security £39.25
# Saga, Volume 6 (Saga (Collected Editions) #6) £25.02
# Saga, Volume 5 (Saga (Collected Editions) #5) £51.04
# Reskilling America: Learning to Labor in the Twenty-First Century £19.83
# Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15) £50.40
# Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1) £13.61
# Princess Between Worlds (Wide-Awake Princess #5) £13.34
# Pop Gun War, Volume 1: Gift £18.97
# Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics £36.28
# Patience £10.16
# Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1) £15.44
# orange: The Complete Collection 1 (orange: The Complete Collection #1) £48.41
# Online Marketing for Busy Authors: A Step-By-Step Guide £46.35
# On a Midnight Clear £14.07
# Obsidian (Lux #1) £14.86
# My Paris Kitchen: Recipes and Stories £33.37
# Masks and Shadows £56.40
# Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed £14.02
# Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8) £46.91
# Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4) £45.61
# Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12) £19.92
# Layered: Baking, Building, and Styling Spectacular Cakes £40.11
# Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners) £53.90
# Join £35.67
# In the Country We Love: My Family Divided £22.00
# 2023-10-09 11:44:28 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2023-10-09 11:44:28 [scrapy.core.engine] INFO: Closing spider (shutdown)
# 2023-10-09 11:44:54 [scrapy.crawler] INFO: Received SIGINT twice, forcing unclean shutdown
# 2023-10-09 11:44:54 [scrapy.core.downloader.handlers.http11] WARNING: Got data loss in http://books.toscrape.com/catalogue/page-3.html. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# 2023-10-09 11:44:54 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET http://books.toscrape.com/catalogue/page-3.html> (failed 1 times): [<twisted.python.failure.Failure twisted.internet.error.ConnectionLost: Connection to the other side was lost in a non-clean fashion: Connection lost.>, <twisted.python.failure.Failure twisted.web.http._DataLoss: >]
# 2023-10-09 11:44:54 [scrapy.core.downloader.handlers.http11] WARNING: Got data loss in http://books.toscrape.com/catalogue/page-2.html. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# 2023-10-09 11:44:54 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET http://books.toscrape.com/catalogue/page-2.html> (failed 1 times): [<twisted.python.failure.Failure twisted.internet.error.ConnectionLost: Connection to the other side was lost in a non-clean fashion: Connection lost.>, <twisted.python.failure.Failure twisted.web.http._DataLoss: >]
# 2023-10-09 11:44:54 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/exception_count': 2,
#  'downloader/exception_type_count/twisted.web._newclient.ResponseFailed': 2,
#  'downloader/request_bytes': 1195,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 155407,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 3,
#  'elapsed_time_seconds': 52.909787,
#  'finish_reason': 'shutdown',
#  'finish_time': datetime.datetime(2023, 10, 9, 3, 44, 54, 251184),
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 2,
#  'memusage/max': 108986368,
#  'memusage/startup': 108986368,
#  'response_received_count': 3,
#  'retry/count': 2,
#  'retry/reason_count/twisted.web._newclient.ResponseFailed': 2,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 7,
#  'scheduler/enqueued/memory': 7,
#  'start_time': datetime.datetime(2023, 10, 9, 3, 44, 1, 341397)}
# 2023-10-09 11:44:54 [scrapy.core.engine] INFO: Spider closed (shutdown)

# %% [markdown]
# 用Pipeline保存数据

# %%
import json


class JsonWriterPipeline:
    def open_spider(self, spider):
        self.file = open("items.jl", "w")

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(item)
        self.file.write(f"{line}\n")
        return item

# %%
import scrapy



class BookSpider(scrapy.Spider):
    name = "book"

    def start_requests(self):
        url_template = 'http://books.toscrape.com/catalogue/page-{}.html'
        for i in range(1, 6):
            url = url_template.format(i)
            yield scrapy.Request(url, callback=self.parse)

    custom_settings = {
        'ITEM_PIPELINES': {
            JsonWriterPipeline: 400
        }
    }

    def parse(self, response):
        for item in response.css("article.product_pod"):
            title = item.css('h3 a::attr(title)').get()
            price = item.css('div.product_price p.price_color::text').get()
            yield dict(title=title, price=price)

# %%
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess()
process.crawl(BookSpider)
process.start()
# Out:
# 2023-10-09 11:50:40 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-10-09 11:50:40 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.13, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.4.0, Python 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:38:29) [Clang 13.0.1 ], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 37.0.4, Platform macOS-14.0-arm64-arm-64bit
# 2023-10-09 11:50:40 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-10-09 11:50:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-10-09 11:50:40 [scrapy.extensions.telnet] INFO: Telnet Password: 13eba7e8fef641dc
# 2023-10-09 11:50:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-10-09 11:50:40 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-10-09 11:50:40 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-10-09 11:50:40 [scrapy.middleware] INFO: Enabled item pipelines:
# [<class '__main__.JsonWriterPipeline'>]
# 2023-10-09 11:50:40 [scrapy.core.engine] INFO: Spider opened
# 2023-10-09 11:50:40 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-10-09 11:50:40 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2023-10-09 11:50:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-1.html> (referer: None)
# 2023-10-09 11:50:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-5.html> (referer: None)
# 2023-10-09 11:50:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-4.html> (referer: None)
# 2023-10-09 11:50:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-3.html> (referer: None)
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'A Light in the Attic', 'price': '£51.77'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Tipping the Velvet', 'price': '£53.74'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Soumission', 'price': '£50.10'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Sharp Objects', 'price': '£47.82'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Sapiens: A Brief History of Humankind', 'price': '£54.23'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'The Requiem Red', 'price': '£22.65'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': '£33.34'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': '£17.93'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': '£22.60'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'The Black Maria', 'price': '£52.15'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': '£13.99'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': "Shakespeare's Sonnets", 'price': '£20.66'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Set Me Free', 'price': '£17.46'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': '£52.29'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Rip it Up and Start Again', 'price': '£35.02'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': '£57.25'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Olio', 'price': '£23.88'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': '£37.59'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': 'Libertarianism for Beginners', 'price': '£51.33'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-1.html>
# {'title': "It's Only the Himalayas", 'price': '£45.17'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'price': '£13.61'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Between Worlds (Wide-Awake Princess #5)', 'price': '£13.34'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Pop Gun War, Volume 1: Gift', 'price': '£18.97'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': '£36.28'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Patience', 'price': '£10.16'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'price': '£15.44'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'price': '£48.41'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide', 'price': '£46.35'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'On a Midnight Clear', 'price': '£14.07'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Obsidian (Lux #1)', 'price': '£14.86'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': '£33.37'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Masks and Shadows', 'price': '£56.40'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': '£14.02'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'price': '£46.91'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'price': '£45.61'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': '£19.92'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': '£40.11'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'price': '£53.90'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Join', 'price': '£35.67'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'In the Country We Love: My Family Divided', 'price': '£22.00'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Nameless City (The Nameless City #1)', 'price': '£38.16'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Murder That Never Was (Forensic Instincts #5)', 'price': '£54.11'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'price': '£42.96'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'price': '£23.89'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'price': '£16.77'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'price': '£20.59'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'price': '£37.13'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Slow States of Collapse: Poems', 'price': '£57.31'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Reasons to Stay Alive', 'price': '£26.41'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Private Paris (Private #10)', 'price': '£47.61'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'price': '£23.11'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Without Borders (Wanderlove #1)', 'price': '£45.07'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'When We Collided', 'price': '£31.77'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'We Love You, Charlie Freeman', 'price': '£50.27'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Untitled Collection: Sabbath Poems 2014', 'price': '£14.27'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'price': '£44.18'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unicorn Tracks', 'price': '£18.78'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': '£25.52'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'price': '£16.28'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'price': '£31.12'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'This One Summer', 'price': '£19.49'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Thirst', 'price': '£17.27'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 'price': '£56.06'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Death of Humanity: and the Case for Life', 'price': '£58.11'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': '£49.05'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Art Forger', 'price': '£40.76'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': '£19.73'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': '£32.24'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'price': '£41.83'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Soul Reader', 'price': '£39.58'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Security', 'price': '£39.25'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)', 'price': '£25.02'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)', 'price': '£51.04'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century', 'price': '£19.83'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'price': '£50.40'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Torch Is Passed: A Harding Family Story', 'price': '£19.09'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Secret of Dreadwillow Carse', 'price': '£56.13'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': '£56.41'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Past Never Ends', 'price': '£56.50'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Natural History of Us (The Fine Art of Pretending #2)', 'price': '£45.22'}
# 2023-10-09 11:50:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-2.html> (referer: None)
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In Her Wake', 'price': '£12.84'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'How Music Works', 'price': '£37.32'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': '£30.52'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Chase Me (Paris Nights #2)', 'price': '£25.27'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Black Dust', 'price': '£34.53'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Birdsong: A Story in Pictures', 'price': '£54.64'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'price': '£22.50'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Aladdin and His Wonderful Lamp', 'price': '£53.13'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'price': '£40.30'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Wall and Piece', 'price': '£44.18'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': '£17.66'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'price': '£31.05'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Elephant Tree', 'price': '£23.82'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Bear and the Piano', 'price': '£36.89'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "Sophie's World", 'price': '£15.94'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Penny Maybe', 'price': '£33.29'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Maude (1883-1993):She Grew Up with the country', 'price': '£18.02'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In a Dark, Dark Wood', 'price': '£19.63'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Behind Closed Doors', 'price': '£52.22'}
# 2023-10-09 11:50:41 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "You can't bury them all: Poems", 'price': '£33.63'}
# 2023-10-09 11:50:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-10-09 11:50:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1195,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 258048,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 5,
#  'elapsed_time_seconds': 1.21903,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 10, 9, 3, 50, 41, 425443),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 106,
#  'log_count/INFO': 10,
#  'memusage/max': 107511808,
#  'memusage/startup': 107511808,
#  'response_received_count': 5,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 5,
#  'scheduler/enqueued/memory': 5,
#  'start_time': datetime.datetime(2023, 10, 9, 3, 50, 40, 206413)}
# 2023-10-09 11:50:41 [scrapy.core.engine] INFO: Spider closed (finished)
